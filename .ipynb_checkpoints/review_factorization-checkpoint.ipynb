# %% [markdown]
# ### Review prediction for Yelp data

# %%
from gensim.models import Doc2Vec
import numpy as np
import json
import pandas as pd
import re
from gensim.parsing import strip_non_alphanum, strip_multiple_whitespaces
# change python encoding
import sys
reload(sys)  
sys.setdefaultencoding('utf-8')

# %%
d = "/home/ruoxu/workspace/data/public/yelp_business_review/yelp_training_set/yelp_training_set_review.json"
data = []
with open(d) as f:
    for line in f.readlines():
        data.append(json.loads(line))

# %%
df = pd.DataFrame.from_dict(data)

# %%
contractions = re.compile(r"'|-")
symbols = re.compile(r'(\W+)', re.U)
numeric = re.compile(r'(?<=\s)(\d+|\w\d+|\d+\w)(?=\s)', re.I)
swrd = re.compile(r'(?<=\s)(,|"|\(|\)|to|a|as|the|an|and|or|for|are|is)(?=\s)', re.I)
suffix = re.compile(r'(?<=\w)(s|ings*|ly|(?<=e)[sd]+)(?=\s)')
seps = re.compile(r'\s+')

# cleaner (order matters)
def clean(text): 
    text = u' ' +  text.lower() + u' '
    text = contractions.sub('', text)
    text = symbols.sub(r' \1 ', text)
    text = numeric.sub('000', text)
    text = swrd.sub(' ', text)
    text = seps.sub(' ', text)
    text = strip_multiple_whitespaces(strip_non_alphanum(text).strip())
    #return text.split(' ')
    return text


# import re
# alteos = re.compile(r'([!\?])')

# def revsplit(l):
#     l = alteos.sub(r' \1 . ', l).rstrip("( \. )*\n")
#     return [s.split() for s in l.split(" . ")]

# %%
df.columns
# Out:
# Index([u'business_id',        u'date',   u'review_id',       u'stars',
#               u'text',        u'type',     u'user_id',       u'votes'],
#       dtype='object')

# %% [markdown]
# ### Get features for users and businesses using Doc2Vec model

# %%
group_user = df.groupby(by='user_id',squeeze=True).groups
group_business = df.groupby(by='business_id',squeeze=True).groups

# %%
# save documents to file

from gensim.models import Doc2Vec
from gensim.models.doc2vec import LabeledSentence
user_dict = {}
doc_users = []
j = 0

with open("data/yelp_train_users.txt","w") as f:
    for u,ids in group_user.items():
        tag = 'SENT_' + str(j)
        doc = clean(' '.join(df.iloc[ids].text))
        doc = doc.encode('utf-8',errors='ignore').decode('utf-8')
        #doc_users.append(LabeledSentence(words=doc,tags=tag))
        user_dict[u] = tag
        j+=1
        f.write(doc + '\n')

# %%
# load documents
from gensim.models.doc2vec import TaggedLineDocument
# %time doc_users = TaggedLineDocument('data/yelp_train_users.txt')

# %%
# train doc2vec model
# %time model_user = Doc2Vec(documents=doc_users,size=100)

# %%
# save documents to file
business_dict = {}
doc_business = []
j = 0

with open("data/yelp_train_business.txt","w") as f:
    for u,ids in group_business.items():
        tag = 'SENT_' + str(j)
        doc = clean(' '.join(df.iloc[ids].text))
        doc = doc.encode('utf-8',errors='ignore').decode('utf-8')
        business_dict[u] = tag
        j+=1
        f.write(doc + '\n')

# %%
#load documents
from gensim.models.doc2vec import TaggedLineDocument
# %time doc_business = TaggedLineDocument('data/yelp_train_business.txt')

# %%
#train doc2vec model
# %time model_business = Doc2Vec(documents=doc_business,size=100)

# %%
## save models for users and business
import cPickle
with open('data/doc2vec_yelp_user.pkl','w') as f:
    cPickle.dump(model_user,f)
with open('data/doc2vec_yelp_business.pkl','w') as f:
    cPickle.dump(model_business,f)
with open('data/dict_yelp_user.pkl','w') as f:
    cPickle.dump(user_dict,f)
with open('data/dic_yelp_business.pkl','w') as f:
    cPickle.dump(business_dict,f)

# %% [markdown]
# #### Recommendation using Yelp data

# %%
## formulate user - business rating
n_business = df.business_id.unique().shape[0]
n_users = df.user_id.unique().shape[0]
row_names = {n:i for i,n in enumerate(df.user_id.unique())} # user_id for rows
col_names = {n:i for i,n in enumerate(df.business_id.unique())} # business_id for columns
X_train = np.zeros((n_users,n_business))

for ib,iu,star in df[['business_id','user_id','stars']].values:
    i = row_names[iu]
    j = col_names[ib]
    X_train[i,j] = star

# %%
with open('data/col_names.pkl','w') as f:
    cPickle.dump(col_names,f)
with open('data/row_names.pkl','w') as f:
    cPickle.dump(row_names,f)

# %%
## NMF
from sklearn.decomposition import NMF
nmf = NMF(n_components=100)
# %time W =  nmf.fit_transform(X_train)
H = nmf.components_

# %%
with open('data/yelp_mf.pkl','w') as f:
    cPickle.dump(nmf,f)

# %%
W.shape, H.shape
# Out:
# ((45981, 100), (100, 11537))

# %%
# predict residual
residual_nmf = X_train - np.dot(W,H)

# %%
mean_u = residual_nmf.mean() ### coefficient miu

# %%
residual_nmf = residual_nmf - mean_u ## updated residual

# %%
import h5py
f = h5py.File('data/residual.h5','w')
f.create_dataset('data',data=residual_nmf)
f.close()

# %% [markdown]
# #### reload values to do regression

# %%
import h5py
import numpy as np
f = h5py.File('data/residual.h5','r')
residual = f['data'].value
f.close()

# %%
import cPickle
with open('data/doc2vec_yelp_user.pkl','r') as f:
    # %time model_user = cPickle.load(f)
with open('data/doc2vec_yelp_business.pkl','r') as f:
    # %time model_business = cPickle.load(f)
with open('data/dict_yelp_user.pkl','r') as f:
    # %time user_dict = cPickle.load(f)
with open('data/dic_yelp_business.pkl','r') as f:
    # %time business_dict = cPickle.load(f)
with open('data/col_names.pkl','r') as f:
    # %time col_names = cPickle.load(f)
with open('data/row_names.pkl','r') as f:
    # %time row_names = cPickle.load(f)

# %%
# replication of method in the report
n_users =  len(user_dict)
n_business = len(business_dict)
#y = residual.ravel()
residual.shape
# Out:
# (45981, 11537)

# %%
print n_users, n_business

# %% [raw]
# col_names = {i:n for n,i in col_names.items()}
# row_names = {i:n for n,i in row_names.items()}
# X = np.zeros((n_users,n_business,200))
# for i in range(n_users):
#     for j in range(n_business):
#         iname = row_names[i]
#         jname = col_names[j]
#         ii = int(user_dict[iname].strip('SENT_'))
#         jj = int(business_dict[jname].strip('SENT_'))
#         X[i,j,:] = np.concatenate((model_user.docvecs[ii],model_business.docvecs[jj]))

# %%
X = []
y = []
for b_id,u_id in df[['business_id','user_id']].values:
    i = row_names[u_id]
    j = col_names[b_id]
    ii = int(user_dict[u_id].strip('SENT_'))
    jj = int(business_dict[b_id].strip('SENT_'))
    X.append(np.concatenate((model_user.docvecs[ii],model_business.docvecs[jj])))
    y.append(residual[i,j])

# %%
X = np.array(X)
y = np.array(y)
X.shape,y.shape
# Out:
# ((229907, 200), (229907,))

# %%
from sklearn import linear_model
regressor = linear_model.Ridge(fit_intercept=False)
# %time regressor.fit(X,y)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=False, max_iter=None,
#    normalize=False, solver='auto', tol=0.001)

# %% [markdown]
# ### Test

# %%
d = "/home/ruoxu/workspace/data/public/yelp_business_review/final_test_set/final_test_set_review.json"
data = []
with open(d) as f:
    for line in f.readlines():
        data.append(json.loads(line))
df_test = pd.DataFrame.from_dict(data)

# %%
d = "/home/ruoxu/workspace/data/public/yelp_business_review/IdLookupTable.csv"
df_lookup = pd.read_csv(d)
d = "/home/ruoxu/workspace/data/public/yelp_business_review/sampleSubmissionFinal.csv"
df_final = pd.read_csv(d)

# %%
df_test
# Out:
#                   business_id               review_id    type  \
# 0      -sC66z4SO3tR7nFCjfQwuQ  Wv-4SQr9UUztIBnjzHu9-g  review
# 1      n3CpBxY6turmqrihCjNbAQ  6CQgD-mC2hZkHLiRSXc3wQ  review
# 2      wtGArpfNEvvYDSn6UVKibQ  CK_jCsfvzX7B4I48gC5fXQ  review
# 3      OtdMMd4taGagxkU88wmEFA  QEJ2TAmUmtcz6rVz2mhihg  review
# 4      tqDwpyCB53TiEIv915Tuww  1u6rTznnVSDgVeaxpGQzKQ  review
# 5      Wa9nN637fEBbcAafbn2c8A  HW4MFsVIeAf8KfcLDfbqXA  review
# 6      5KG0A3WlC7K3DAXtrIFFjg  wgZptlK7ArG7kRA78Xy26w  review
# 7      h6jfMpTZpNduLG0wE2tbaw  CfZAWA8uPdyHqC43PPV5nA  review
# 8      ntJAKLAq0cXzzdFgPoo0Iw  -2l-Gcro_paZuc5PV_Rg8A  review
# 9      83RLRT-MsvXQJrmIanqVYA  -KkgInOPKWxjvZwVvV0zPg  review
# 10     0CHZQpLljhYz2hBcwDHECQ  Np3RBYyE8mHC6di0w2MDUQ  review
# 11     o1W6gwCqnJqvdCenLWz5GA  jkiwMKLQUqSik0qnnzYfxg  review
# 12     qZCtzJCdt29_DdYD8US9FQ  TZAa_61ODaRTDzEWwPY9yg  review
# 13     pa6K7DGByxBXxcVJ59nWMw  4Q5srbbkdjZiZloSFsGxFw  review
# 14     53YGfwmbW73JhFiemNeyzQ  XnRbUSFZB5DieSHrBkV2ng  review
# 15     35uDzLpJlbSztgkJLtg1kw  kEYEqY1Qs-W3Ise4XDiIdQ  review
# 16     IWwt0vm8lYbVoyGSPd2Z9A  O4zfvsFXaXnISEiL7DuELg  review
# 17     Ctq1_p6fOWBiX9n8qaJT6Q  OPud6_T25yny_veVFgwnpg  review
# 18     k8JnZBspVOI8kLcQek-Chw  6o48ylH1Pql0j1kN8ZZt0g  review
# 19     78dfzUUVUeFpcYKqvs_X1w  RhcChIyZ5s3gey-Mj73QBg  review
# 20     OaTFqMIAHUhJckgvbP9IXA  nnYjybfVAGcT5UVsdyaOTQ  review
# 21     L_MtTn4IUBTmQtqqM2iFqA  a7dhJn5OGvIl3Kyu0f7h0g  review
# 22     midf9OPxhqNLHllywqcZ_w  Ci1l0cBIW-xJ4mPoHot_tQ  review
# 23     U7jOpLoLXYphWFqS6JO8mQ  GwkfBs3ryGV4qochfkGCJw  review
# 24     QnAzW6KMSciUcuJ20oI3Bw  fUJFwZ3EwLGmWbYWjbDHGw  review
# 25     s1dex3Z3QoqiK7V-zXUgAw  OlzwNYEfzv6ALBmcjuI7Nw  review
# 26     VOaqbEwHlZeLStU911PNHA  pDEPW6gEYsWl1E8ZNkSJeQ  review
# 27     Nq7eB1wB2EArUICtiNePvQ  0hcPk_NBDwWhPVMLIWs-0A  review
# 28     XYhVyCbzJCrYclR6J4LYSw  r-PpDp7XxuvtD3vhCAcn9A  review
# 29     N9m4hZHAvbIgAuulp0lftQ  6rK3nDr6cSYNdlaBXX8VFg  review
# ...                       ...                     ...     ...
# 36374  eJpr6Ks8pr4bmvDVPTN-Xg  iqcbTz_RJah4vwpitKTEYA  review
# 36375  DDnmNTvIIQu2t3WZ2EQx-w  t3aX5r_SVwADHn7VarQLOg  review
# 36376  w534NlI52Y0RAzwOZrYmTQ  SdSKUnW2KaWdkgKz4HtOnQ  review
# 36377  6y2w3rT4-w3-Q0yWQ9yZeg  sTDhQa_JpNFxXgZWHuP_WQ  review
# 36378  NkGQRN6ahwQoFEAlHq8NHg  XG3GcJsAiSVGgnzhayRDmQ  review
# 36379  Bjt3rB73dvSDe1XEPEWc6w  4iMX-rbOBhK59Ehb7QjiNQ  review
# 36380  x_mxrJALBi5No9CxRswEaQ  CwnTkvwegtf8G4TM0KSNbQ  review
# 36381  PCd22VEO3hrNsi_E2rh4nQ  VejTclfq8Ao71OTzaZbVKw  review
# 36382  2j-g7OkNc_kSMUhEeRGANw  Ih0FQGL5MOs9ZcIZ4RGSHA  review
# 36383  fVgrpVyp-nPLTac9YIjTug  jAIi7X9ciPRWq6Dixml4Bw  review
# 36384  y0weNFCIJF9bTgBbFST86A  V887RGwMPp8v24MHZzul6Q  review
# 36385  6zd_tZhd5kdKBj76ztjyTA  E6ZKibPhyOzw1Uw65xHNcg  review
# 36386  e6SpV25uAEfwvP1_FmPuig  tZG-nMWVXGQHGKHKdzHyaA  review
# 36387  5cA0fBYsNagnDot1AATykA  vMT1WETnN976N50gxp5OkA  review
# 36388  HKr_xfeyrv2Bh7urZsQEVA  quDFF5nSqQUwVL_lr-STpQ  review
# 36389  xOlzK02DWzETeZ8HbiEB0A  MKOz0-1KLsntukDuTMSAlQ  review
# 36390  G79f36rYTCkzsgl2YyqH5w  CI6CU5fS3AontDP_IIl-4g  review
# 36391  yPJFfglhMHAKciUpjTmgBg  a5MRSIJnwhDNAjwys5QXFA  review
# 36392  v7OwbHgNgy_VQ9eP5FjvUA  mGonNlxBr25034CxJ_R5xw  review
# 36393  6BN01-NYYiD0FjDG49nIng  9oQ6CjdwGENhKOarcDoX0w  review
# 36394  VEojEXbJ81eiPLSSF9jNEQ  78a903TwsITBy3IEbk05Fg  review
# 36395  eGevCRobYnA_HSj60sEWvQ  HDIaMOkRRkH0abL_Ud0rSQ  review
# 36396  g-eZgnBDvSDguF8cUxKCkA  eQdqHUd3YCQVwosd-qjCpQ  review
# 36397  vARjqeIkSNsazHltujiq4Q  9BKT45M3l43RA4xWQIaBQA  review
# 36398  _ufhmY-588fNlV5ers3UQQ  XPVVj6euWlw7vD2i3tcvKA  review
# 36399  OyehKmT9fPoin5jzfJZ0Fg  aHCyoQlIbZZF9p_vWLszfQ  review
# 36400  rrDyZPQiWjoJofWqyl6Tqg  VTWw9fW1uX0GOr8P38UbdA  review
# 36401  SDwYQ6eSu1htn8vHWv128g  LjxtpRnPLAIh2klYYuAxJg  review
# 36402  IWwt0vm8lYbVoyGSPd2Z9A  bV8d3wt7gJ9RIKYal1vxwQ  review
# 36403  9mQj65SmYj2pcehH339aEw  dgxzPpgR81qIcdQyF3Gr-g  review
#
#                       user_id
# 0      dqeFcKq2L2wiOg9LFT9-UA
# 1      XZxDoqyUJu2qMOY8HiEDsg
# 2      QMlaWJt4zVVWzv_KQ2scew
# 3      weYT-xJwz8o7mLNWIhD6HA
# 4      gQm2p1gmBPQ4f1sHxgRlbw
# 5      PO1H81tZBIjRK84sWpCsVQ
# 6      979X2L-2jz8fwOVkSkMpFw
# 7      R69oePjuaeq9jwlI7cqCPQ
# 8      BlivVzHUCuCIzMngqlauWg
# 9      XVa0c9vRTnL3z-uvd3idvA
# 10     fgrzZ0wl3M1D9nLAygAtuQ
# 11     q2Jg-AUHB-Nf1AcAP3-MDQ
# 12     NvDR3SPVPXrDB_dbKuGoWA
# 13     hIb1ikbIMI0t1EK4gPsK_A
# 14     hYnXUHTSi-a1xvPGMrWgoA
# 15     TlEfizHjEaVlLpYt5oKZRg
# 16     t5EuasjAlznZgw54_fNJWQ
# 17     nVKK_YUK_aweRMQjumFKyA
# 18     M6Wi9pKDx-W6rGgmf9GVMw
# 19     hXvwAS4f5yXs9lK-OBWAnA
# 20     YnHYlN1m7jDhAH9XgR4Dlg
# 21     0dpNmJxKp4Ha-fzJ2R8cCw
# 22     2h0A-NirfNl2p2SquFWYHQ
# 23     Kt9NwDONle_mc0QHTud9jw
# 24     fezRz8fMPcvCFYuQu3XamA
# 25     exefpuK6O1ctUUqTxq5XLg
# 26     iabNwwEWKA4f79bvGY0kvw
# 27     V6oaaZWuqaULJc6gYD8P7Q
# 28     v0WVAfhqvAIWEHiOaOxx3Q
# 29     gtxvx1Nc_5a2c_2ca3fQtg
# ...                       ...
# 36374  0bNXP9quoJEgyVZu9ipGgQ
# 36375  Gt_ah4qdPL-j2k69yYgIrQ
# 36376  8-InERGLhHGjX3DZPFXMqg
# 36377  cZTeOE21RCkqpXqu7V9T5w
# 36378  vv4DP0GzqK9zSaNkDK503A
# 36379  v26k4Bzy9GiLLlSmDk8LfA
# 36380  N4mJVevofx-7vqW32Qle9g
# 36381  YrYxEQmacf0KN6pUuACCFw
# 36382  -1RSOrp4T5n4cQn0HhW1RQ
# 36383  tyUClbogMKu0Ny5b1O0rxQ
# 36384  xGhFrP2FhmRGs0H0tOH3ug
# 36385  fwEPqYiyZCaB7QKY6a7h5g
# 36386  rfCLIn8CPQ5L0yw62fKdIQ
# 36387  Get8vmOQU19enueHAiYt1Q
# 36388  zJk8Pd-0oY_1m23Xragu8w
# 36389  0cYm4CW2l--szcovxF4BOw
# 36390  lyoRtqeVTqHzMmjAqDyEqA
# 36391  pO4p5qoWkbabSzThk3MJqA
# 36392  8dYSMRZ1DwIHZFogFXkbrg
# 36393  vNWcDZiWimb33WQ8Fr61eg
# 36394  NnjybgQ1b9_lnIbJNQ42yQ
# 36395  m1pMCsxajdV17rHLI7PPsg
# 36396  o959bSCJ_NzD6skRIeFXnA
# 36397  Ju-rMUfxp-GaxCez3Sv5Xg
# 36398  vBvTK-Fqfhl_DACCNaNOWA
# 36399  Bj5dFX6pz4XiImXHd0UJxQ
# 36400  ayKW9eWwGFcrtJaHcwZUCw
# 36401  6cqaHBhtZvUuFzb00InbeQ
# 36402  qJ2Q5zTaW15hHjg4Lug0EA
# 36403  hiAqcQ1ilOaEdGzMYAAq8g
#
# [36404 rows x 4 columns]

# %%
from collections import Counter
Counter(df.stars)
# Out:
# Counter({1: 17516, 2: 20957, 3: 35363, 4: 79878, 5: 76193})

# %%
np.round(1.70)
# Out:
# 2.0

# %%
stars_mean = df.groupby(by='business_id')['stars'].mean()
prediction = []
for b_id,u_id,ind in df_test[['business_id','user_id','review_id']].values:
    try:
        i = row_names[u_id]
        j = col_names[b_id]
        ii = int(user_dict[u_id].strip('SENT_'))
        jj = int(business_dict[b_id].strip('SENT_'))
        feature_doc2vec = np.concatenate((model_user.docvecs[ii],model_business.docvecs[jj]))
        w = W[i,:]
        h = H[:,j]
        score = mean_u + np.dot(w,h) + regressor.predict(feature_doc2vec)[0]
        score = int(np.round(score))
        if score > 5:
            score = 5
        elif score < 0:
            score = 0
        prediction.append([ind,score])
    except:
        try:
            predictiona.append([ind,int(np.round(stars_mean[b_id]))])
        except:
            prediction.append([ind,int(4)])

# %%
prediction
# Out:
# [[u'Wv-4SQr9UUztIBnjzHu9-g', 2],
#  [u'6CQgD-mC2hZkHLiRSXc3wQ', 4],
#  [u'CK_jCsfvzX7B4I48gC5fXQ', 4],
#  [u'QEJ2TAmUmtcz6rVz2mhihg', 1],
#  [u'1u6rTznnVSDgVeaxpGQzKQ', 3],
#  [u'HW4MFsVIeAf8KfcLDfbqXA', 4],
#  [u'wgZptlK7ArG7kRA78Xy26w', 4],
#  [u'CfZAWA8uPdyHqC43PPV5nA', 4],
#  [u'-2l-Gcro_paZuc5PV_Rg8A', 4],
#  [u'-KkgInOPKWxjvZwVvV0zPg', 4],
#  [u'Np3RBYyE8mHC6di0w2MDUQ', 4],
#  [u'jkiwMKLQUqSik0qnnzYfxg', 4],
#  [u'TZAa_61ODaRTDzEWwPY9yg', 4],
#  [u'4Q5srbbkdjZiZloSFsGxFw', 4],
#  [u'XnRbUSFZB5DieSHrBkV2ng', 4],
#  [u'kEYEqY1Qs-W3Ise4XDiIdQ', 2],
#  [u'O4zfvsFXaXnISEiL7DuELg', 4],
#  [u'OPud6_T25yny_veVFgwnpg', 4],
#  [u'6o48ylH1Pql0j1kN8ZZt0g', 5],
#  [u'RhcChIyZ5s3gey-Mj73QBg', 4],
#  [u'nnYjybfVAGcT5UVsdyaOTQ', 0],
#  [u'a7dhJn5OGvIl3Kyu0f7h0g', 0],
#  [u'Ci1l0cBIW-xJ4mPoHot_tQ', 4],
#  [u'GwkfBs3ryGV4qochfkGCJw', 4],
#  [u'fUJFwZ3EwLGmWbYWjbDHGw', 4],
#  [u'OlzwNYEfzv6ALBmcjuI7Nw', 5],
#  [u'pDEPW6gEYsWl1E8ZNkSJeQ', 4],
#  [u'0hcPk_NBDwWhPVMLIWs-0A', 4],
#  [u'r-PpDp7XxuvtD3vhCAcn9A', 4],
#  [u'6rK3nDr6cSYNdlaBXX8VFg', 4],
#  [u'jRDmnBRAsyuiMe-bwHcODA', 4],
#  [u'1c1F1gupYv6c-DKjroPCOA', 4],
#  [u'9j0maNhcKThXi_PhrabfIA', 4],
#  [u'ouPDdGaLk_MCC0Hxi_bV5w', 4],
#  [u'N1OXAumpHTuKHRak6fo8_g', 4],
#  [u'K3q6_B6d8DhPSuf4xmKhiw', 3],
#  [u'CmQ-ftH-4mqLOOZpv6ndlg', 3],
#  [u'Yy90K-U-kRbvY0J0bFFQXg', 3],
#  [u'nKOyGlvhsQjB3xDT7su3RA', 4],
#  [u'cd3IjxTMaRWovINs_l1jfA', 5],
#  [u'Wgd5OzoTzze9clteH0i0fA', 1],
#  [u'wAZPCbhkaj-i8g48XN1ImQ', 5],
#  [u'NAxYJXk_HKOLLs1xYAuckg', 3],
#  [u'p6xAm5i6lvJy_DAh0YLmJA', 4],
#  [u'a1In35v6ApE46-XMnUWTLw', 1],
#  [u'aqdlkrQKyR3zMeeKWcwZmA', 4],
#  [u'y5dhSBQ2oubvmlwiP0MElg', 4],
#  [u'vOXLsOvboB1AgWbEeodkCg', 2],
#  [u'TD9z4v-ONSW3Q9pWQzlKlw', 1],
#  [u'CZkBrtCpEchjbzTrobSzyg', 4],
#  [u'M0cnoCoj3y1ovIWSG9yzTQ', 4],
#  [u'3CHNbGmn_jBFlzprKvQUyg', 3],
#  [u'oCM0V43-YlT47_h88kJC_A', 4],
#  [u'xiaMLrCS0-rr8Kxhm_uWdw', 4],
#  [u'9k-X0IpTBOtB0LLuROGwnw', 4],
#  [u'K9L4aOI5_tiZVAXB6TroGA', 4],
#  [u'Cu_ZvYTdjsJR88x4ZZCKRQ', 0],
#  [u'wvJLIeoqWk_UlKkGpXrkmQ', 2],
#  [u'XQt32DOUGC4JNma0FwnlRA', 2],
#  [u'mt3oeIZPOSpsrfhOXYfqlA', 4],
#  [u'Feq7BsHwFDuAh9eTVQNpzA', 3],
#  [u'FqFGY_-hZiFNqZQeSxwa6A', 4],
#  [u'Ye-8f718mo8NWUrRotvBtw', 4],
#  [u'kyK7gqfIMz1xDTg9b3iPFQ', 4],
#  [u'jOuKGWalka8K6YZSySeG3g', 4],
#  [u'K783m_J2XC7yIve-hup9Og', 1],
#  [u'zyaA29zO5QdOiz_LSyK1PA', 4],
#  [u'MSutefRGb2a2u1L4Z6FwZw', 1],
#  [u'lyxEcLHfEaF7WSZZSxXlKg', 1],
#  [u'zmdsyWzXemlkNQjUiYVZTQ', 4],
#  [u'yDSWcI4ufEeYhp7m6KjkYQ', 4],
#  [u'n8Rzg7O346lNqflweg835A', 3],
#  [u'Wa4E30GuIWT8Z7ROjQy68w', 4],
#  [u'Gavawlr96fSE9Nugzyb7vQ', 4],
#  [u'1voeA2wwKQT5vFW1Ws3VVA', 4],
#  [u'mG-Kbv3slg8Yd6K-fK_ssw', 4],
#  [u'1MhzHYNOIAH4KBJz262Wbg', 5],
#  [u'm-ZNBKFTYrrTXhI2ilaf9A', 2],
#  [u'gYyhbMTsDBn1chdQ1sYIcA', 2],
#  [u'Te1K1yemlCUTOVS_82zGqw', 4],
#  [u'_2QHKAhmJoq8cLJeNdfuGw', 0],
#  [u'1p4hmC_EAVLVwFkXX4QuAQ', 0],
#  [u'LEGx21lRKpLtuAReiAIYfg', 1],
#  [u'wZ1J6izoboUXEAU00k3z0Q', 4],
#  [u'JwsjG2wZjYvHYRjq7TEN4A', 1],
#  [u'3dV4kIXegl8ysJtuuSobUw', 4],
#  [u'wey2w13ZCaXOOYBn8GiQwQ', 4],
#  [u'B3SwfLBX5wXQmm010hs9gg', 2],
#  [u'fZ1BH5jd-Kutkokdkb6zLg', 4],
#  [u'UBCJWY39uNAEN02qoxsreQ', 1],
#  [u'geFdIVidIXgiJUZCh50JLg', 4],
#  [u'35Wpg6iKNFMtOhXCGlTC-Q', 1],
#  [u'3mjJDFvhEllFbkgEA_shIw', 3],
#  [u'SjsbyCE25MHSI6k8DzrAQg', 4],
#  [u'WRZzr4JyG4jDPVsCk_oe9A', 1],
#  [u'krjNvirdPbpt7PdMnRmdoQ', 2],
#  [u'm5Dj9q16ASjh34MsJvjSpQ', 4],
#  [u'dd3IFB1Kgi7viQ94YzEjfw', 4],
#  [u'dSDjCqcGZKJucCowiBt9jg', 0],
#  [u'SiH5lG-ZoSKXN00iU6Vkjg', 4],
#  [u'Q6ipPOWwbQ45THjBuzlWmQ', 4],
#  [u'UeDKDD-dU0rxDghrK-pS3A', 1],
#  [u'8yTVH5mK3KTKxULkzdVipw', 4],
#  [u'-86ZKy7m73LZ9KnhpylSHw', 3],
#  [u'SQpPj5anc0HW9-04wtabKw', 4],
#  [u'P7_63pEokkqadQj0wZydEg', 4],
#  [u'Rsh2CSTHXO9m2FoOkVdj9A', 4],
#  [u'ubkqQRf_c17Lj3hCFJKd7g', 4],
#  [u'3vmUnfNkzJl1LKZip4T3Dg', 4],
#  [u'MapcgBkI0v5pGDpyBLrBxg', 2],
#  [u'Zyo3Po__kxYyKFMIgJEAwg', 4],
#  [u'Vmews_PmA92QwroHByMWJQ', 5],
#  [u'n_F4tetikzXJaaO-YPc2Dg', 0],
#  [u'wjYwqQG95O4jnxz3BOMaXw', 4],
#  [u'v-wZdZUOQrC-kcLUo7LpjA', 4],
#  [u'PWWSir1owUbX-eIjt7G3gA', 4],
#  [u'Sp2FTbw8iohFC-8gP_bcIQ', 1],
#  [u'XAbS9GosUTEt3rGGDONMpQ', 3],
#  [u'o8URRD1UKExYXYdawRM3cA', 0],
#  [u'yzq_SIyme89F3QhAroAdvQ', 2],
#  [u'PFn2E5DNt5ULqO-4CgkeAw', 2],
#  [u'JuPxpV0wu7ZEbzQoItdHjA', 4],
#  [u'X2tY2zavmHDUy6aJrAgGuw', 4],
#  [u'cHOJ-h4bq1K33Fv5Zxnm1Q', 1],
#  [u'Vd9E6n0mIhfXQgbZfE_lwA', 4],
#  [u'16TjuS5dAnaNJEITi7kv4Q', 1],
#  [u'THScd4acwJuxDgyNO-tYoQ', 4],
#  [u'wrhJR2xn6k4Ts9mwzTgzDQ', 2],
#  [u'9NLjTx8AdEzn8mTyTHVR6w', 4],
#  [u'Ek47OnljBubWk09sWbuHfA', 4],
#  [u'O50d5HILvLNk3oup1ANgbw', 3],
#  [u'xdn-qmK3FmIL46xB29tZSw', 2],
#  [u'rg8cUtGHyVeIUKE3RGZ-1A', 4],
#  [u'gQ2wn450b8y0mS3B7mkYpA', 4],
#  [u'cHeHx9i_x2x3OCXswc8WSA', 4],
#  [u'zOU_Y87Kj8ndmXTFdk76gw', 4],
#  [u'GkTEqfJI3wc_pIJ0_rZNgQ', 3],
#  [u'cImRznqZ4nFKJ4_3Q3b0WA', 3],
#  [u'IYMYblqg62zRb3VnhO4SVQ', 4],
#  [u'iynSbjh4cMozF124dQ90fw', 0],
#  [u'vJmpyysuqUbPpGpGR2Wp8w', 4],
#  [u'GXP6ZlbscSLfQtTiqSPsLw', 4],
#  [u'wBPYiVo7odIsw-YRxey8aA', 4],
#  [u'O-Hp9bx3dfSUmpsEPO0Ykw', 4],
#  [u'eti3tBBY7nD35F6eu9oAWQ', 4],
#  [u'8alS_UOie7x6C5PvoGHKSw', 1],
#  [u'tP78iSpaOVuCgIA2noVf0w', 4],
#  [u'YAbWn9F7KxlomiuIoeNqPg', 3],
#  [u'KPwOL62aW2CvJiJDezQ7Ng', 4],
#  [u'kxNzXpR6VlJ8bkYT5mMueA', 4],
#  [u'PC0oNbcg9d_W9QtWuWuhQA', 4],
#  [u'xVWOUY1OmbscMR0lCc0K9g', 3],
#  [u'_2urQ2SyprV0AWx4Yc8BHA', 4],
#  [u'PY9qH_FYQyRrsaHosWLkYg', 4],
#  [u'vwHgu6zD6YWQNXMzMEhfEA', 4],
#  [u'7ADowiMH9qBCYuy0t8ofZw', 1],
#  [u'PGqO_rvg6JcBFo4l4DIkhA', 4],
#  [u'_eBpnJDBS4axOsxqiH-W4g', 2],
#  [u'w0k-bRS-OUMh8GydMoSQIg', 3],
#  [u'UUTdjl4FEehcnrJChbuInQ', 4],
#  [u's30HWbC0127JQeK1bIJ6mw', 4],
#  [u'icOwZJqRP4yFBemMVhOKzg', 4],
#  [u'W5AA0Ihm0HtkdWlc_behkA', 4],
#  [u'l_JwiI7cor5BM-VFOm0b3Q', 2],
#  [u'QIhUovjMz0wtuQ4Ld6bPbw', 4],
#  [u'v_9oXmg8KHlpQCRmy6rvnw', 4],
#  [u'zufFhD8thKfBwEioW2owDQ', 0],
#  [u'mNhSQb6UH39WpQ84_BCOsw', 4],
#  [u'9uy7PGdJ1qk-hKtin5CfIA', 4],
#  [u'lL3vcYtreXwWy7fvwlfH7w', 4],
#  [u'AWQozO1JIyFWQTDZWYhO_Q', 4],
#  [u'V8FLJnC3kmPSQyoxFbwPnw', 5],
#  [u'czLGSnq7KZ-T0aJ0bjFLRw', 4],
#  [u'wBiOXQttbWaXFbUnZpEXZQ', 4],
#  [u'SXAY1sK0uD-gV1WlXzUGUA', 4],
#  [u'-ZK5w6o776UGp5DFNwOsxQ', 4],
#  [u'UKb76lPUOva93_7Juwr7Wg', 4],
#  [u'Hv562efQ3sR-g5r29R6o1Q', 4],
#  [u'8v4cKRRPdYlcmPKGft1B2w', 4],
#  [u'cmS48ixKLzWpfmJ7RmmHQA', 3],
#  [u'xwrtutZ1MwGBUSa3kGd7iQ', 4],
#  [u'rWpBTF-wDG2tA_PW0WuM5Q', 3],
#  [u'2UCEjs21XD6qGJrZYBI3CA', 4],
#  [u'nRrzDWq0AMA4JUgTd4Sgsg', 4],
#  [u'jEBN7ktNnNJD8T6WeGzLvg', 4],
#  [u'-qF8dr0TvC4YJxalG2bpow', 3],
#  [u'vlEYNV9Lakg3gJt9o7fs4A', 2],
#  [u'Ds0y2VhFnPS4cbLiSod0Sw', 4],
#  [u'chlu-3_B1qBWos5iVK7Dnw', 4],
#  [u'ZrKa33XYUC96rfxWPGAYQQ', 4],
#  [u'Fr5UlTZCdzY9qNLSOG3hew', 4],
#  [u'zph4YWuxLYtVAqECL0qPyA', 4],
#  [u'dG2ukIzPzh7sHoiFJ4qkMw', 5],
#  [u'AaIhanO4rgQAY-5cV9QhMQ', 4],
#  [u'AuqclmInh72kHLLxAgRjKg', 4],
#  [u'x9KSePePWiXOTpFV9LhIXw', 1],
#  [u'tzteD-RJ-c-6sUz6jYw5YA', 4],
#  [u'geOCPVe-H02B0CBxbF0Xkw', 4],
#  [u'_Ydq_JTkXFebPXNZvZXl0g', 4],
#  [u'u8O0UGRJSkrHLD916EyLOQ', 1],
#  [u'_15WjjQUTQUdHbOlHOm3Kw', 1],
#  [u'tW1QXt4U070LLf8qokXU2w', 4],
#  [u'Bm7PE7IPdG20-I6urAhyaA', 4],
#  [u'8-lERV0SQFNPVaNzyqJ42w', 4],
#  [u'b1rhaHsK56XBPhW0fWdX4g', 4],
#  [u'5vFdupadkVpF7G7G6uH9zQ', 1],
#  [u'a6nZ43DDTJAd2im877DvrA', 4],
#  [u'WyQzpITCMSNOAKKJV9d6ew', 4],
#  [u'xLIRh2IM86NXJc9SgN8T1A', 4],
#  [u'fIsdvR5_ZSPxjx6ZpLUpMA', 2],
#  [u'AVbFSbY-jbC9BedRzu6fyw', 0],
#  [u'gYPeLy4JfW2MB4uf-VApkQ', 4],
#  [u'_GHfL3xSRnvZqRLxHwUMxQ', 1],
#  [u'5bGHYJAq2wn78jEALOmwAg', 3],
#  [u'F7uiY0fkG4t3cWDf5MKNlA', 4],
#  [u'mu2xIIIFeAkwtqtC7LZgeA', 4],
#  [u'IGf2YDYrO8X_cNFMqfY6fw', 4],
#  [u'feDY9g1N8Re1gXUUHPawRQ', 4],
#  [u'gy6KDrH8AiEELEMp1YZeBw', 3],
#  [u'1TcdI_q9LJ7MHtlsqlG0hA', 3],
#  [u'FUSRBUZCUkv_-gTvjXENKg', 4],
#  [u'hbRuhnpL7Z95xgnH3qplDg', 3],
#  [u'OPnXetmXF_aD3vRSfMu9eQ', 1],
#  [u'KS2PV87FlvvNbvJ0GsgOVg', 5],
#  [u'mobsyIo38aIf7zcRKQ0pBw', 4],
#  [u'm-CVgaZkmGL4kSZ-pJSZsQ', 2],
#  [u'4pvbyw_rZ7ktJpsLMSGumw', 2],
#  [u'02FNdMa8xQ8lcOO3iQTEgw', 1],
#  [u'y0JX14NTfsyhv5J87sZYMg', 4],
#  [u'pFNhSwLLRAHDbvjRFTHgNw', 4],
#  [u'YU0v1SjByhn9HqDejT8-og', 4],
#  [u'ZJzbNF33muFQdLG08MjzcQ', 4],
#  [u'k10-soGbKjNhpZ0yLAFc-A', 4],
#  [u'NFPS_PltE0bbngTWPPB_vw', 4],
#  [u'kKRsQQN68vqAz3tHhHdtwg', 4],
#  [u'GwMSEybSf0EDCJxw_oWuJA', 5],
#  [u'o1-VkJtd7_2PN4xwO436mA', 4],
#  [u'oAOCh6-Tp3Fz5jF5TofsSA', 4],
#  [u'eLa72pLXGiuLcHNAQcVj6A', 1],
#  [u'Lb02vxUz04AbQ4Ij918Yjg', 1],
#  [u'9VM85FN7AEzSzYYKqU7IAA', 4],
#  [u'Yf7qSjSptgTMzZrDgacLKg', 1],
#  [u'dZte3eyTzIxGQmBLzMUgDw', 4],
#  [u'ZscQLyCheJYvxtFbJkS24A', 3],
#  [u'LrcWjgrzroAuOUhTws3Oew', 0],
#  [u'DQY2K-7r_xxrKxnxYOkqcg', 4],
#  [u'dGA-Ggt1NRoC3ksxREaSdw', 0],
#  [u'7v6zNOs6A7KYFikQHvv_qw', 2],
#  [u'iEPpdvm6UGcozuoIlkGjzw', 4],
#  [u'cud5QoBto2pJC1124I9ppg', 4],
#  [u'y-dwbZuWUlxdn1fguMuL3Q', 4],
#  [u'ZZIYBlgigq-rjtnPd9kb5w', 4],
#  [u'X_1hCyaPP80PcJV8SMUlfg', 4],
#  [u'rTw2c0ko7SnPTTF96vQiyQ', 4],
#  [u'yzrh8WoxBZ6XjIxjxm99_w', 2],
#  [u'dkzkOocNYfB_giCIwuIsxA', 2],
#  [u'RWI5nKI7xK_rsg5rduzz6w', 4],
#  [u'E_jRebDqQLBjZEiOfF7naw', 2],
#  [u'jGe5AJIc5UbGcOtSw2qm3w', 4],
#  [u'SVhdjGcR4n922CQfUag7nQ', 2],
#  [u'KEfMUKHPZoKU_FzuYSS-XQ', 4],
#  [u'd_zQ2lVpJzltw1MyqekwQQ', 4],
#  [u'dOYS3SEte0UYIb6S8_fMaA', 4],
#  [u'y3Ra1zYQKGZuESoLFKtFMQ', 4],
#  [u'qw-2-B_hHTpfGfhx1sML4A', 4],
#  [u'0_74xiRNGilaVAIl2Hr4Cw', 4],
#  [u'bgy_A_TVwd9QgS0X2jmaJw', 4],
#  [u'3orQGJtVrps6sOSkO0zIBQ', 3],
#  [u'_yUIct3bjl8uV_EJrh4CcQ', 4],
#  [u'BumewFRNJno8o631RyhF_Q', 4],
#  [u'BmhmSenkS1SvsOBSaRd5tg', 1],
#  [u'IgDo4rSeEAD5vggP77xyXg', 0],
#  [u'QpZV2phnCizO6SAlRkoCpQ', 4],
#  [u'H6fqQ2nF5Fvg0gGkxgmJXA', 4],
#  [u'a-z_qZ-Oohur2eZ27PJPag', 4],
#  [u'DcggjhCvms1n0eRnrKNwUw', 4],
#  [u'OsD1Ul3pPvdsD5L9kU7JRQ', 4],
#  [u'3lMpOTjP_TEgxKEYubdyNg', 4],
#  [u'GWlbfZlb1Cw-Yk92pZ-q1w', 4],
#  [u'HnYir0UO5Hh0MDPTM_CBKQ', 4],
#  [u'rLHXReDIDjtEbqhdyRktkw', 4],
#  [u'44RhRx-D0zfJUEhMGidbmg', 4],
#  [u'H2xmaFXyozj2lWoek6CTlQ', 4],
#  [u'DNuCQR37bEqg7iAOObz7QQ', 1],
#  [u'V1XKuBlYmnlQehvd6D66iA', 4],
#  [u'munkgmMhHgwzRnih0Jkwig', 4],
#  [u'Kb1v-2WAgrKotKCKBiJnoA', 4],
#  [u'HJxSw9XjTy3UvfqTzWS_OA', 4],
#  [u'YyMwNu-0JYmFbx7QWYoVpw', 4],
#  [u'Ngmzd--u8hxeb4CaJZm_EA', 4],
#  [u'RuyrseAikN3eNVOt3GpnbA', 4],
#  [u'jOjaXlYTYSp7sMiESnpk_g', 1],
#  [u'PTIs0eZK5r4c7ez0w24eKg', 1],
#  [u'xu2ebLiTOX2lSI7sDuvoIg', 2],
#  [u'0HwB-8C62K0REQRI_P53Mg', 4],
#  [u'Ve8lIXttnSPVg-UsF79d6Q', 2],
#  [u't9NjBrVYQaG4r_2ViCzFQw', 2],
#  [u'RyuCn4hPZmuvRlL9bqcj7Q', 4],
#  [u'qNMVUZqbTJnT4lScZogXWw', 4],
#  [u'TAs8VCBKLKqsaWO0nuXsIw', 4],
#  [u'-roOPhTpGwB0TTYX8vJfvA', 4],
#  [u'Z0WRjfOXBsDJDFAVQ2VARw', 4],
#  [u'Q5E5wr04b9GMPx8NnJKuOQ', 3],
#  [u'klpivuUUGWQPNk4PfMKnIw', 4],
#  [u'SGzP8-JyBy2EfDXpW0Qy9Q', 4],
#  [u'swsm-PUuzaOrz_087JxrvA', 4],
#  [u'ILECW1F6HAYDuEhDWnjuYQ', 4],
#  [u'wuN-aIQXrgC_V2G8vLB8sQ', 0],
#  [u'Evm2-ULK7mlzLO2btwqvPg', 4],
#  [u'to0c7y-MLZMakOP6WnNBZw', 3],
#  [u'3HZOjoEsVs_wGfPGZhaL8w', 4],
#  [u'WLfeCAQxTxKhni8-EdUzLw', 2],
#  [u'GUYciEtB0xZLhf7dIAgJ1w', 4],
#  [u'a2YEO5fL3j3BlDCPp5ElrQ', 4],
#  [u'F1chaF0Ec9WWxyaF9EW2TA', 4],
#  [u'jcyiPg38912d3piWGr8FoQ', 4],
#  [u'1h0PFilp5XztGsSgNAQs8A', 3],
#  [u'l-EFuYa5-KFkxNqAdGQexA', 4],
#  [u'N525hBaePbR1wIZ-AhB_kQ', 3],
#  [u'b0bMIaBNY8pXl5M5YcjR_Q', 2],
#  [u'QaI7eCDqn_oTJ85KxuLHWg', 4],
#  [u'bZvybTBrEL4WpPSVoeJB1g', 4],
#  [u'eG8CrXeHZY6fDFbFGrRSSw', 4],
#  [u'FkOuvv9YfSWxdUnlpLAKdg', 4],
#  [u'f9Cnw_xN3ktIG1JWoslzUg', 0],
#  [u'x0nujg1Fxfg2sYFTXx6Klg', 2],
#  [u'r11qDrnIas6RVYo2BhpEVA', 4],
#  [u'4bfAYC78cKFnmMo0GkT4hg', 3],
#  [u'ixTY81_i_6QziA_JdCmnMw', 4],
#  [u'9NX6Uac-Vu2_yyB3ON_bgg', 4],
#  [u'HKHSbv-MOVMlKEJR-l0YOg', 4],
#  [u'EoJ9zwker4B1KSH8Sd9Usg', 2],
#  [u'y_qsVQYsl5GkjI0hCpsWwA', 5],
#  [u'N4t-7wGeoklz5LqaimRfvQ', 3],
#  [u'7kok-qzsAPHIMP1GCGx-Jg', 2],
#  [u'jvIn8EhAeJsRVYKk3yWskw', 1],
#  [u'sEsv-50nt98vDb4HcLY9qg', 4],
#  [u'2jHF0IOvEZqf0634wX9H9Q', 4],
#  [u'pHHbPUMbkG6LVAaKKvksXA', 0],
#  [u'RsMBwWHgOT_DUhW6dxZPNA', 1],
#  [u'd2IYvTnZ7Uam5csdhYCe7g', 0],
#  [u'WWfdK4q_Etm4IwkH2VA4hg', 4],
#  [u'ADMdp0Gu73aMi5-dj6AHrA', 4],
#  [u'XmHlecpEkI5T42MjUrpSWQ', 4],
#  [u'qJ3JcseY8s5B74imFdpxgg', 4],
#  [u'N95V8lNgClxjHdbRea97zQ', 4],
#  [u'BVKY3vexPMAqD5FuwPDljg', 3],
#  [u'5ACWP5Y9d0HxzSFfSrxx3w', 0],
#  [u'r96uGFCrjTM5cIfQzS5W7g', 3],
#  [u'hiVjOAWsWzwTKW6GKGcX1Q', 1],
#  [u'xoQH0PXKACQRctVyB9whuQ', 4],
#  [u'aIF0dqTNEjemgu3sDQ_BUA', 4],
#  [u'SfvjSwHus3Yrf26ijnvysg', 4],
#  [u'uONNsgdVkcxDYqxKIjoqiA', 4],
#  [u'9Uc5fA5S_8scfd15Cg_L1A', 4],
#  [u'hslPCUgLSSg8q703IoX0zg', 4],
#  [u'd5JrBsP7246dmyQAia3QjA', 3],
#  [u'2TJoOPZOX08ghduOWqfuyQ', 0],
#  [u'HBHJPBFN2XDfb2ba1yr7Nw', 4],
#  [u'1lBfBMiOxZnnoHPcYPCm3w', 4],
#  [u'WZ2mARu6mxhOLnNYG2XF9w', 4],
#  [u'8cD0O3Lbbg5SoCM0541D6Q', 4],
#  [u'tJ3R7H-OLojcL0qEMDaPQw', 1],
#  [u'-n7jvXKtQa6pOyyEImKSPg', 2],
#  [u'PLMr6aiD69_WXt8saWGkcA', 5],
#  [u'OXPpjnAxRlcxII8XPFj8Pg', 4],
#  [u'emVmuq01FpgQfjcyzuA5iQ', 5],
#  [u'2Y3LBOtzIN8sM_Hhn26K3w', 4],
#  [u'l8jlwyjYtGaYp4AZ_BPFQA', 5],
#  [u'UhlwJ5bQr-eKjdqqCji6ag', 1],
#  [u's_bedAK1t05C7DaffuvK0g', 4],
#  [u'drTicw2NZEu-xeBdQLQHqQ', 4],
#  [u'ZNiP7LpsV-MZuaNFa-G4ew', 4],
#  [u'fJTYV2we_8g9vvG0_Hx-5g', 4],
#  [u'KL8-9uash0sD5SIHh8qDkQ', 4],
#  [u'Mo5kV6ZngKtNMTOUJLPtCw', 4],
#  [u'AOQXKAd9qKOA0YKj2p9sxQ', 4],
#  [u'vvZtIZAS6clAW3b78j-BXg', 4],
#  [u'_6wLUWTlg8r07hPewJb0wA', 4],
#  [u'NjpL7sGoVCqZ-ZVWEVpf8g', 1],
#  [u'vLCjv_g93XTvhmgApWsP_g', 4],
#  [u'--ZC_Ts9Hrn-pKOUvBgkxg', 4],
#  [u'2DyUtTmuwm8tcUEfpSwq2Q', 4],
#  [u'Bg0iFtqqhUi63ItVj89UcA', 4],
#  [u'lVspEruiNApyy-QnASIQDw', 4],
#  [u'lsYlzb6TkVcPIGdDyFtZeg', 1],
#  [u'-OVi-sAFIbIteMh9FRNPuA', 4],
#  [u'S1NoUuTNghOU7YtEFmBL3Q', 4],
#  [u'fX86I0NGFvG5SubYDmblWA', 4],
#  [u'P_3vEYXdkrBJeaTT2yzpGw', 4],
#  [u'El5KWSjbfOO7IrX_eicD1A', 4],
#  [u'ZQmuPghnmTtFJ8L82Q_Vxw', 4],
#  [u'Ahtp5KJEkqorgln8tjkAog', 1],
#  [u'9fFFQMo4lVMRKVzthJRCrw', 4],
#  [u'K2XUYl4MZZuxS9DDFBBDwQ', 4],
#  [u'bZiT-vsAFAp93a9hJza8nw', 2],
#  [u's2wxXcpC-np9xjEBtQ1wpA', 3],
#  [u'iFxXin9yeV-eLiiDFdxndg', 2],
#  [u'QVcOazClBDQZLCgLb62W7g', 4],
#  [u'MBcyCe7YxfhInd8-bXlRpw', 4],
#  [u'1Y98ss8OhsyfsCwSot7sGw', 4],
#  [u'WIz0ZeKeupj5nX2WU6RVsA', 4],
#  [u'soo5OwZzOopTiTwN-yu0HQ', 4],
#  [u'Tk6q5ZHjQWPOzIGFnUkTQA', 4],
#  [u'uKvLMBKiLyAP7F4AxFSI0A', 2],
#  [u'QBbXDvNLO0YVvHDjlplarg', 4],
#  [u'w8uAcyc0l-M1MDitSuIaBA', 4],
#  [u'wL0vMc1yPvRT_CuSuacPsw', 2],
#  [u'cO_alFrOEnZHeznPzgJt6A', 1],
#  [u'DA-MD3E1ZVpnWX0RqTdmzw', 3],
#  [u'1vSfru0kelK1SlWq0BV-5A', 4],
#  [u'YAZihvhVr6qreq8mSJYChA', 4],
#  [u'6DVDpUUMcAVEsTxIow8zmQ', 4],
#  [u'EdXbY7iJSHE_kqSulEhIEg', 1],
#  [u'zGgJCUWxe7gvE8GSkrhtqQ', 4],
#  [u'5h7_nl8dqY2NcqXMlN-QRw', 4],
#  [u'-1nlmjb3zKEXd0vz_nqpIw', 4],
#  [u'2ZIGrCKOOWfnUjxGHsgB-g', 5],
#  [u'YxQAu1mSOUtpj6A5FZyK6Q', 1],
#  [u'AZ4E0azIbst2Lo6oaduQFA', 4],
#  [u'9PrD2jIoLiO5WTMFrmxlmg', 4],
#  [u'LAfkFqe5W8E41yKHjfGXew', 2],
#  [u'incwskDG3zLBpk06D383tg', 4],
#  [u'YwurN9FDjy_3Jb3AX3HY9w', 2],
#  [u'jomUN0gebpymX-TJc_zamQ', 4],
#  [u'vD_43WRbpc6K8q8nf75hnQ', 2],
#  [u'TFJ7a7c1vLmZK2mWrEMD4A', 3],
#  [u'cEqONCpaEBDHZC4TH-iNXg', 4],
#  [u'3vMyvbJ9qQTnp3agiNi8cg', 4],
#  [u'rL9cmhOYuJdScYiEN9uFMw', 4],
#  [u'8m5QdOABg8Sy3ZLq4L2JQg', 3],
#  [u'a-QoSWtpTpqpRilfUWwGYQ', 4],
#  [u'4DeFc7hm-YtT_U9VxWoDxQ', 0],
#  [u'y331wgGhXKzp6udKpGohNQ', 4],
#  [u'skZSscC7WLTqo0uAdXgZ-g', 2],
#  [u'tDhJyjBL7NLPXOyaPDwnCw', 4],
#  [u'8hMGBc-0wDxGwvzY1RzLow', 4],
#  [u'y21u-YFW7z0tYp79hgLhOw', 2],
#  [u'4usBzMu5FhEOe3tsCZ4zwg', 2],
#  [u'HSRkwIN-bO-zFcqsZHxr0g', 4],
#  [u'Q29gfUVfJg5i1TeuZ7V7uQ', 4],
#  [u'3ZBz9KVeG3Ur8EqacxOLpA', 0],
#  [u'qyah_zz1OnRrCWcOYhEWcQ', 4],
#  [u'SXVEPopXQzQtJdFW0G43GA', 2],
#  [u'cgKBWt8d07oQ1_6vMbVGjg', 4],
#  [u'Iq5oVkH7InCS8feVgx1jqA', 4],
#  [u'hbw_EkS_LpFE2sz6PK11YQ', 4],
#  [u'ylqaeQpxyr7ZeqD2NdgJPQ', 4],
#  [u'wV5hY7eez_M48rmjyoVZfw', 4],
#  [u'mRpEBlTtzHB5Gzm52WCX5A', 4],
#  [u'ZOXD5tpCOQf1_Hck_tevgA', 3],
#  [u'UzRswf8q5aw8PEjzNV8RuA', 2],
#  [u'xkdxlkoUsHDEV1uU4Qdqqg', 4],
#  [u'9pPTe7WuoxqJGLDwOaZU8g', 4],
#  [u'UuFNuY9t_dZJiLOSafYrsQ', 0],
#  [u'fbK_YkLxBc1DB6tWYJri3w', 4],
#  [u'YtAlRSkDGhEakXz1eRkktA', 4],
#  [u'3Gna7PixoEtv4kP9PLTF9w', 2],
#  [u'nI17aRpAPo_ghszPoY7b8g', 4],
#  [u'w44Yt7Rt1yT71iWU2aFteQ', 4],
#  [u'fWnqALV-TXfzkFgy5CoGKw', 4],
#  [u'mEYWj2R5bee--MH2tGEuVg', 4],
#  [u'hQWr3VjY6SySSuYCZCuK-A', 4],
#  [u'sRNdjEJ6VuyiRGID4sM6qQ', 4],
#  [u'Nfo4FXWJZDpdDV4Kuqva0g', 4],
#  [u'FpxeCjGRFGbqJnQtpSfP1A', 1],
#  [u'CQ_NRfzrv0xCFtLPJjsqDw', 4],
#  [u'e0cgLrMwAzHIWXy3FAcedA', 1],
#  [u'iNOcQ889Zefs2AZ6u6P9Sw', 3],
#  [u'GQngk5BCzb6NfE6YA-H8Bg', 4],
#  [u'IFPpf-vjevCpQRSYOrqlHg', 4],
#  [u'rMPFbiC8UgaqICjJivgidQ', 4],
#  [u'PoutxxwMsWXVagJNiZmakw', 4],
#  [u'wE_n8fm4Pe1Il0JUdC2EIg', 4],
#  [u'96tfd8cVn5umVVc6eKGapQ', 1],
#  [u'xwQwH4RfNU8RrnkkC5kncA', 3],
#  [u'evF4W11U3WmdIcNxLW1wrg', 2],
#  [u'rZ38pvBi8ACrN8O_pN6uyA', 4],
#  [u'vRsinhCdEXmfN7_F14fyug', 4],
#  [u'kmq9dysWooK5kC50ZGYbKQ', 4],
#  [u'tRMti1PWYoiTRNZH2Ndndg', 2],
#  [u'rGi8IEnmOKPe9sAiPc325g', 2],
#  [u'sXYoyfp_DTikKVRimScmYA', 4],
#  [u'18OzYcw48boozRjdmjQgHQ', 4],
#  [u'yFDHeS5xBVn6fofydezIkw', 4],
#  [u'c8aZcn6MPLlEzWWGW3hzhw', 4],
#  [u'flDvdmERfKceZ3mo9XhVng', 4],
#  [u'01r5-gybIX3uuqJEQWXB7Q', 0],
#  [u'4Bbarhy35Evgdfkwo-wGIQ', 3],
#  [u'clGqq6urSD6T8mXlxjA8WA', 0],
#  [u'YABma6aywKFskFuCDymFPA', 4],
#  [u'J__yGLqaLv9W-5re4bKJ6g', 2],
#  [u'ZOBiUR-o0F3_lHJA4FlK5A', 2],
#  [u'og4WEEuAKCzEGOTOomZxQg', 4],
#  [u'X5gj_A41cJORSOF5k233Mg', 4],
#  [u'BuaZh1YNvYGt6XlAO0IjiA', 4],
#  [u'e4OCK8ydz26I4y34k6cINA', 4],
#  [u'YiPyeF_3dJEo7b_Vv3p9iQ', 4],
#  [u'5i3NMSU8rl3-pDWuZQtX4g', 3],
#  [u'bYqee675a8CbbkhcWwnADw', 4],
#  [u'2mUZGOVAu3FYGiw3x7Q4kQ', 2],
#  [u'aN2UVENep4hADJqfzAdjkA', 1],
#  [u'bYrRTIlvHifMstzJ3wuvzQ', 4],
#  [u'qOmfcWmf_eDygy69D9TpVg', 1],
#  [u'O5kZYj0_DrYh1QBSEwoLTA', 4],
#  [u'eH1_wmXfsl_1qf4Rr5CYmA', 2],
#  [u'FoNt3yjyq9qDt5BdH3ZLTw', 4],
#  [u'YfiuBQi_FlRke27O2sI0og', 4],
#  [u'yxCC_CYtXSMidhZE2zCBpQ', 3],
#  [u'bp8dZNhYfV796TU_h0SKPw', 1],
#  [u'v_vdgLvRv9LDnfSj70w-_Q', 4],
#  [u'5ElmZwomrrxwVortaZOvqA', 4],
#  [u'jkUrLhMoHxhpO-_XZWym_A', 4],
#  [u'BP7H2Gvb4GYxk9S2v3C2Zw', 4],
#  [u'KqvIEotXpva4LJ1YQk1ISg', 4],
#  [u'3-X8da-CWdcn8rYCgYZSGQ', 4],
#  [u'x_C4_Dz1jnEKT4l3MuWpow', 4],
#  [u'wj27gnEUaovfo0l0QBYcPg', 4],
#  [u'dWGjonNmM9iWni9Z3KWf-w', 4],
#  [u'GJHlzzZNRov3XZG8PkP6Ew', 4],
#  [u'_U2228AbWDiyhV-NKw4owg', 3],
#  [u'YnSi75DouGPfWlKuKyTsKg', 4],
#  [u'a0viInoSGZ9Z0stG0mTUDQ', 4],
#  [u'4Ug_Y1YcEMCgOqfiPA4MQA', 4],
#  [u'LObs6KX1l17kVcrjz8AWWQ', 4],
#  [u'XiQfxh-WSA3IbZyWz3DLkA', 2],
#  [u'35w2DdxKkh7m3UuZWFAQXA', 4],
#  [u'RAdYigbcYQj4fDACFTmxTw', 4],
#  [u'i4IYwIo6YjkI5SklpPzgBg', 4],
#  [u'fE0GPB22uks_bdYILXI7vA', 4],
#  [u'9RvH5nXk7Z7TwGNybLW2hA', 4],
#  [u'bO5bdVYOD9FCXZLSjoNZCQ', 1],
#  [u't6Ydei058vPVvphRmH8BfA', 4],
#  [u'266P0cx1SRNDvBrvfCL7Rw', 4],
#  [u'C2s9hxSZsWZhTET3rIWZ2g', 4],
#  [u'AzvKns1P3F0_sA19J0mEOw', 4],
#  [u'rMxQQqU4A0iPpj7cHYBLaQ', 4],
#  [u'JrlIa-U8HV9ccWnnQbZMWQ', 4],
#  [u'_r9E3SZlOSfxcRQozu7vvw', 4],
#  [u'1QJdOnHeRzrN4w0L0MfkHA', 4],
#  [u'N2rEInzRfoZkThFVONq0jQ', 1],
#  [u'fsUME7a_2uGdivdrH36x8g', 4],
#  [u'nmWImPymE-pPtypa_uDLHQ', 4],
#  [u'0EvUNpizT9NjaNIdgeMiAQ', 4],
#  [u'z_DmjdmXjNa3xxesczbpSw', 4],
#  [u'csDQqt-WjZrmPq7WCDcMEQ', 4],
#  [u'MudptPt31o2s7RvOgDg5Vg', 2],
#  [u'RCQj_kVOqas4ABm_rM-0JQ', 4],
#  [u'xTjcA-TWNXeOlElyNElB-A', 1],
#  [u'uVQKXZdl1JDljFXhybp59w', 4],
#  [u'f5geb7VfNXe2NLWFnUjN4A', 4],
#  [u'zwhqyBGpzO0sznEKqaWUSw', 4],
#  [u'G8zFr41ZJJcR1cHAqtr-lw', 4],
#  [u'BAcoM5mCioCbL2e9YLYl2A', 2],
#  [u'olwuX5jbnVAtWq3Ac2LDsg', 3],
#  [u'5YcUCu849OU9aLMxZVI1Lw', 4],
#  [u'53exDoJCexAizBbOYQPbbw', 3],
#  [u'EhWVf0sk5D1HvD6IVxXZmA', 4],
#  [u'O3Q8reMPF2EeyC6k8xpCLw', 3],
#  [u'rgxK8EbkyeZLmCm2yRWTTA', 2],
#  [u'MIhD6w9fxSCOznK-5nP2xQ', 4],
#  [u'rC30XAwaB_0Qr2N3kNTMRQ', 4],
#  [u'iZkod3m0ZYhem5xf4rP9ww', 1],
#  [u'9QlDg34EZL4Ui4ccvW-BOw', 4],
#  [u'DkVWQv3CCAsibz4FBqMrBA', 4],
#  [u'ghzg9rqebv_q7iCsBR6Ggg', 4],
#  [u'cc70bKnGk32wuKscNweYwQ', 2],
#  [u'SGoF9VUOSKa3n_NbrFieBw', 4],
#  [u'eoq3qBoZA49c5UnvlDBvrw', 4],
#  [u'TJeEoFNYse0CqYNo3YOU6w', 3],
#  [u'ZCmgtK_riZYVRtN4ULldBg', 1],
#  [u'MnAsrifsl67_deE8Y997qg', 3],
#  [u'TSR2S5ew8nuobTdBZyOCSA', 4],
#  [u'nVBGZ39oGa7xivu1LGRFIA', 4],
#  [u'8lxsn3r4JYdk28lbA0vwJw', 4],
#  [u'k6FqncAW5ppA8EPBuQ3qNw', 4],
#  [u'RudNnGhW0pJoRz8UCXIAjA', 4],
#  [u'hkC1RcMIJTnB686C_EqcXw', 3],
#  [u'Dwl_l-2Rg6zkqRz1ISh_2Q', 1],
#  [u'SrlX_Ikjr3PnJAQPj9SVTg', 4],
#  [u'zxei7Ts3Rdm9ztA28dKeRA', 4],
#  [u'orm9a1otCn5Lu6JiRP1SRw', 1],
#  [u'sJIMTAtvSWrlxvCkEZBxEg', 4],
#  [u'cyHUr5CAGEFUsMIbEJzbwg', 4],
#  [u'F2uJ70GSff2qSfjvkyvSnA', 1],
#  [u't7063hwgevkmOg9rjRslRQ', 4],
#  [u'9JxUm7Bfqm_a9nhky5xIaw', 0],
#  [u'zUX5xPRZ3_-XEDIZyjQg0w', 1],
#  [u'5N_IzfnG0FOIzo0KBOl6pw', 4],
#  [u'45l5K-y_JXFFk8bppn9GrQ', 4],
#  [u'iIiZ39ckxerx9hQov12Mrw', 4],
#  [u'51aRp94UqKss_JALb3Q-9A', 1],
#  [u'ZXJ2XrM9xWUpsqLkFns5pw', 4],
#  [u'D0JL1CjHmMzIVt15Qma0Tw', 4],
#  [u'gsug2VShTgJ6bFHr49Y0zQ', 4],
#  [u'9IzT9hSMMzTZbjOUxSdIbg', 1],
#  [u'qx_tA09R7q1unCsqN4C01A', 2],
#  [u'wJsBbez6C6Sk53Hf7bVjow', 4],
#  [u'dmjXxnqDYGKO9UOnMWFczA', 4],
#  [u'H4MFRooNUq6qHa8oR5bVXA', 4],
#  [u'ifa4oFovK_iN7naJ7JjoSg', 4],
#  [u'y7MFIlPVSocBjkNKH4cgOQ', 1],
#  [u'3ipLLRECx-duiUcqg68H1Q', 4],
#  [u'XceHepUpv6jmySCRyqTE7g', 4],
#  [u'cM-7b1UmCH06DNtDkCu-ow', 4],
#  [u'0hvkOOZrvav0KRTXnoFmxg', 4],
#  [u'I1rOMFtxVYCQCRei8CLhFw', 4],
#  [u'4VtuGbdFV5hoV0g3IRM3Zg', 4],
#  [u'COK-TGOwA19IVHnnaYRIYQ', 4],
#  [u'VjvhdcweYlSxoQ0VQBnOcA', 1],
#  [u'tE-ONHhvp7YGKeMOIzdTlQ', 4],
#  [u'3d9AD0VF5C0adiqEX2jf9w', 4],
#  [u'MSd2cSxxKClOglCeb8H58Q', 4],
#  [u'8BmISXBzUEUG_bzuREdMAQ', 4],
#  [u'Zi_vf08chLuijBu7H2NT8Q', 4],
#  [u'sGsyDYQmIVJeHx2SVJ5fJQ', 4],
#  [u'69vC7R8agyemzyGKn8jUPQ', 4],
#  [u'V6oJWIoN91CBDYWvtBWOIw', 4],
#  [u'eFzASlU82SKXMHs8llhODw', 4],
#  [u'FV0tex-2S79wAmL09gMe7w', 2],
#  [u'_dqd3J0sFiUSybLtuv1fmg', 4],
#  [u'8Wrx-FPbEUbLD4t_XJmEaA', 4],
#  [u'oTUwTPR7VJsQZmdLFs1NzQ', 3],
#  [u'jMVpshOkA8YpxRd_yk-FjQ', 1],
#  [u'c4MF9DaD8v38tlpI2gx1DQ', 0],
#  [u'V7VviXkIVILzrpLm6aZd6w', 4],
#  [u'gRRkQujtonK84JsVJR0TaA', 4],
#  [u'0Y0Wci8GRJCDC6RES0TEdQ', 4],
#  [u'f3MEvfGcs1WDTBlWs8sVyQ', 4],
#  [u'e09uPK4pAVwPYo8r5Ft0XQ', 2],
#  [u'odZT7e6wAAhGXQcd4NtSnQ', 4],
#  [u'y8GE2wwdw0Bge7HpgsVJtw', 4],
#  [u'WNsfo9X1Avxh8TNt5tXRBA', 4],
#  [u'PqQWdd9GDA1zQBi9S5eGlw', 4],
#  [u'yA3P5ohiNgf19OOuvwWCAQ', 3],
#  [u'cO5D67AmRXU7lWMzF_BX7g', 4],
#  [u'VTHsk7bYX4iPamkXhhQASA', 4],
#  [u'LtmsvyUdMxLbIdftiit5fg', 4],
#  [u'fCbYV96qeNrhlWHhqmiA2g', 4],
#  [u'UE75BU3o8N8V9AXgdFMhIg', 4],
#  [u'NCwqY3mxaWoJQFqnjA9rWA', 4],
#  [u'JTitmjPdp196nhr8Ze_Hwg', 0],
#  [u'uOiXCAZ5imscXmJ1CTitqw', 1],
#  [u'Vz-Lgcls3ygMf0veeUZAJw', 4],
#  [u'2k0qFXVkn7HqLoGT5cB0SA', 4],
#  [u'MnHYFdm8xzGJq8h7T8eGbg', 4],
#  [u'bzrFWSLA2W45oQlqlUB9mg', 4],
#  [u'Sip5qyHOMl_KrALOUAesSQ', 0],
#  [u'91KIVrHy4fS6SVgenjgsMQ', 4],
#  [u'-imuQBVrFajDU05tm5iKiw', 4],
#  [u'GbYI7-k7-MWoXSs3DtynEA', 4],
#  [u'g9XjwVvYuxiGthlwlJwS_Q', 0],
#  [u'qOCGYEHARMocMyOy665ugA', 4],
#  [u'asRRuFzwg9Mlkfi2bBctgg', 4],
#  [u'nE-5u7cBBJcli5aN17fH-Q', 4],
#  [u'eggsVapvQHzG8WIydA03MQ', 4],
#  [u'zABJE9Z3ZTuwn40IRgIy5w', 3],
#  [u'cRjHzZoDWNVbgRDM98cKYQ', 1],
#  [u'CsNDrP4uynQlxj_AijYhcg', 1],
#  [u'd_MyLShDIoXkUPcT6_Yurw', 4],
#  [u'GKXE6K0MwCp1fQoclukdvg', 2],
#  [u'sqHHlMquqg9oCK-EUy0SXQ', 4],
#  [u'dhqx1oZyWylT2DNEt14YOQ', 2],
#  [u'ZvtQNGBEYXWyI6cCBeOhQw', 4],
#  [u'qPECz-8EPGKzgaWtb6VGrg', 3],
#  [u'BhxDoPCcuqr8USHn9d-EUQ', 4],
#  [u'0gle6blhKTv9CiU6OWOm7A', 4],
#  [u'219Djg0LeKwu-dZ6jQr6ig', 5],
#  [u'KEOyo9TkFVKXtjTCErtBtg', 2],
#  [u'MltngSz-KyjmynJKRY2GKw', 5],
#  [u'FaSCGgAO6etApMl5obSEiw', 4],
#  [u'8dZFTTDR1r83ea0OtWpyXQ', 4],
#  [u'yDv_L9nk0r7S7_p2vqvJvQ', 2],
#  [u'_oiQGI7JTm0SOfrew44q2A', 4],
#  [u'5Z0habhAagHGSnKQMVbzkw', 4],
#  [u'MO8hbbiv_Bvn56CHz37rLg', 4],
#  [u'5LYG5PkDn5y0UEaoYsLZUQ', 4],
#  [u'SJGbJm1WENtcb_psQQgDkA', 3],
#  [u'Z0u9Psb7xIkK_5WACYdfUg', 3],
#  [u'KFuSjqB9SfZDLzakajwMhA', 4],
#  [u'a0E0QAGMUcdPENV_foh2nA', 4],
#  [u'JoFVw4G8lYfvqTFt631x5A', 4],
#  [u'gTTbcFhTa0GgM84ppX3ykA', 2],
#  [u'Ulej4wz_hPKNV8PsiZpJbg', 4],
#  [u'Kab_BmPVG-2HjO-I3HAIag', 4],
#  [u'hoY5-6DlncNnnzGSma0qdA', 4],
#  [u'o9eOS0SrfI3BdpCRgYyf1g', 4],
#  [u'FIGG4m8wjDgsBpC5fOhydQ', 4],
#  [u'U-UUb7KdMv1jvLyhoWNTMg', 4],
#  [u'RWyjgnYeOduh8QfaXRqMjA', 4],
#  [u'tm7C7x31VSBoCpO0BxZuqA', 4],
#  [u'OD13b-Xb5YWHej3ec8wcsQ', 4],
#  [u'gxgSdV4oDQhu6O3nNqB67Q', 4],
#  [u'R1qUfn7ifLuqAmqMq0RMkQ', 1],
#  [u'aulgp-72JqCrlpEkbjQZdw', 4],
#  [u'r68wEh-oTAVPjqw3LRiLlA', 0],
#  [u'Y6-S0Gl_ck5Ywjjlw4BLWA', 3],
#  [u'BYDzDpHOMIOFFQ2fSowGIg', 4],
#  [u'V2jkC-UMfOykZe7feCtsjw', 4],
#  [u'gls8o7JEzb4NBZWYJe7kyA', 1],
#  [u'8-LRNkd2TpJq9h5uiXaNDA', 0],
#  [u'e6ujBlZdx9MbemK48nbvhw', 4],
#  [u'E4n3oonMxtdTG6nnKWJWZQ', 4],
#  [u'TmP2B8PWAEA7xLyDRdm6zQ', 4],
#  [u'nYTtLW9ZKoE8RYJcxPDniQ', 4],
#  [u'HrfOD1PvRQ7zL8NFhYppIg', 3],
#  [u'0KArRkOuXICeo1Dz5Ag9_Q', 4],
#  [u'hCCYJn0hCH7iq3_duQ1aoQ', 4],
#  [u'X7RTMXkKAdXW9y4UJdPwxg', 4],
#  [u'PZC_YcRjdIGUBBKPDDDy7w', 0],
#  [u'Plm53nnZ7wLZQxxAUYazKg', 4],
#  [u'E9O3vws4s5W3RXB9N5mFcQ', 2],
#  [u'yOe1lLMG5U2DHC9FDWyJtg', 1],
#  [u'PxXTOf9RVgcqM51STnKXDg', 4],
#  [u'mm-qWm4Gg88NQX5wlIpl5g', 4],
#  [u'IwVfKMl-6Cpa2dqrdlCe9w', 0],
#  [u'Gj1uivlVIzbctgFZrIdFow', 4],
#  [u'MLwthLF2eGi2HcrhiJCDQA', 4],
#  [u'r93KNLju_4urzmuASszV7g', 2],
#  [u'-yUkbFhDFR5IE8njpopbVQ', 4],
#  [u'tFX9V9oHRxiH5KlLNPzy9A', 1],
#  [u'lakaM3R6FP7FScW3gRJAqA', 1],
#  [u'45GUeh9Sn9bCEDour-fnnQ', 0],
#  [u'ojdjhm3_4nSjtOo8ggBQig', 4],
#  [u'EDYxzbgCMQbK3e8FVNU18A', 4],
#  [u'HgeHN3m4GL6NC1GOYvjGqQ', 4],
#  [u'CWtSR3050AY8Sxg9ErIHXw', 4],
#  [u'ldlQPlMxLQ4hgx4iNGmQ1g', 4],
#  [u'uffm5ybWOyi6agdQS246fA', 4],
#  [u'fqzm1nXIi741xByEUSrIrg', 5],
#  [u'Ok5j_JVKgDohpgcvhSqb3g', 0],
#  [u'JKbvYgY3CMwB8NppEJreAQ', 4],
#  [u'GPcVxTZ9OvplWBJJgKT98Q', 3],
#  [u'iA8opti2vOiNYnWZw3RMoQ', 4],
#  [u'-X3eFadtGn0PIqsXH2srOg', 4],
#  [u'KLQbrkhvDmoybfls9z3rmA', 4],
#  [u'cIj7Jwwkga5vDC0NwRmUPA', 2],
#  [u'vCsNMDMP9h7uY_zNhRbhaw', 4],
#  [u'dJcDxx_2TnkCxEOQP96i7w', 4],
#  [u'ftG4diSu6nLj6u-_1MeXXw', 0],
#  [u'CagILnF9QZEaZZQo-n_4dw', 3],
#  [u'vO2drTlAdUB6GNU9PmPivQ', 4],
#  [u'O2HOzhJVLXAcw7HkWwCcqw', 4],
#  [u'Jr5hfa5opjwENTjYN2D1pQ', 4],
#  [u'ArXVE5s28CTS8lulPnEdIw', 4],
#  [u'7nDcAGaJLtWOM_LwA2oR9g', 4],
#  [u'ZfkjMnRILEMMJq08oHj4Uw', 4],
#  [u'MKJvxCjRjJQRK_hgAp1dTw', 4],
#  [u'ozQFBW1Jk8_YqmnH_EERXw', 1],
#  [u'x0aGwOrbvcgkxJhK35trfA', 4],
#  [u'flOBFGnfDzKQdXHZQ6UhCA', 4],
#  [u'4rE9Cjsy_viOo9qsi4o5xw', 4],
#  [u'o4dI2qixDqKX_4NHCfGGtQ', 3],
#  [u'TjI70-XQuhZOl4WmLlSBcQ', 3],
#  [u'xN2CrhhbTK43VKaQyP_jhg', 5],
#  [u'pB5kyuIBy9Dqbgj0IRucqA', 4],
#  [u'nvm1S9on5bY_vA0OjZfCAw', 4],
#  [u'2uLbiiocAvM49irUIMca3w', 3],
#  [u'6oplSphZM9ZyBc1q4ePgVw', 1],
#  [u'gFn3BXFnjkK1WFMq7IkHrg', 0],
#  [u'poxO3KJl_2l0A_C7O715EA', 1],
#  [u'3cEHzLEpm4NmFcl6gK0EkA', 4],
#  [u'V4HOMsvuZ3Xs7zudxyFNHw', 4],
#  [u'9_VzCu8vZ3ousTvoS_zxxQ', 4],
#  [u'Fu624wB8L3Bn0h_OdoclyA', 0],
#  [u'NT5Ml04AUvkIu2bG26wbog', 5],
#  [u'nx_l4dw0XKvrt7AR8ePfdQ', 4],
#  [u'oZmumrmpvKJdiv4ssatfiA', 4],
#  [u'2ZgeQQ6X0WK8ZYmJ9OVeVg', 4],
#  [u'0O7gl-PlXD_MSXKuGWF7bg', 4],
#  [u'0FUIoS_nQx8JmW1QkMY7Sg', 5],
#  [u'CF_fh70Ci7XbNMNFv2yvvA', 4],
#  [u'B9ENW_VdFuaMbrgpISytxg', 4],
#  [u'SYUMY2pY_od9MILMMG2bBQ', 4],
#  [u'oQR_dQfQOIhCLTxBKkZbiw', 4],
#  [u'koxrpbFf6UtK-YGjuMqfHQ', 4],
#  [u'JtB9Dk2qGeN24Zx56EVSyw', 0],
#  [u'M_Rw2cJkBcnwf72kXQ-XlQ', 4],
#  [u'Zu41Kgz-v7y4dxiFiPaoZA', 4],
#  [u'Eq5IAo_fF849B2R-3wQ6ug', 4],
#  [u'nPWj2Y2JnsEjH49Azvsy5Q', 2],
#  [u'C4NV1wkqcnIlqrrn2mqv0w', 4],
#  [u'op4LDBSZL35ulhlHwtadAg', 4],
#  [u'3LeoHGM3lSuUzI1IskfC_Q', 4],
#  [u'xlOid-_aDpC2Err9R-G_hw', 4],
#  [u'5Z9i7D_1lYfZoicFUOX9TA', 0],
#  [u'8ZPhk6edt46CDDZNurZ4bA', 4],
#  [u'7ZQzf22vaHp5z7JmNUTeOg', 0],
#  [u'CMJZRVAD8IT0O9jFBpjRpA', 4],
#  [u'Cja5m0-UAw8iNwq1tdHcnQ', 4],
#  [u'KuwU8lnYQfX2VYX24t11hw', 4],
#  [u'ObFYZRIG2nXcOsBdG_yPPA', 4],
#  [u'0uw6lfDDXanwLPcRjAWN8A', 4],
#  [u'cPisOg5KKVuJ5vcjuCG9dA', 3],
#  [u'nrLzgOuzhYNhEltcOcsq0Q', 2],
#  [u'DTAv1KWzxDTU6AGmeXqIUA', 4],
#  [u'pbEue8HSa7eMG1iCUOeG_Q', 4],
#  [u'CWGrx1IsJNykWNFRug7Few', 1],
#  [u'm82P2NpEMwo4Y69P3z4sAA', 4],
#  [u'HbDhmaF95jgd71c7fP1hrg', 2],
#  [u'LRTCJC8ZqQO_EbKZiHM3EA', 4],
#  [u'lxWGC9VQGy5hyZo1rlf4Uw', 1],
#  [u'gLZlWmF70BECyKC8fPq3nA', 4],
#  [u'xrNpLeaWngX8tWZwrvaZUw', 3],
#  [u'8dtjRVDpdrC1ObwJITtAMA', 0],
#  [u'23eChdtOmZO_Aquf76b0eA', 0],
#  [u'_OddV9I71LO1uGkTP3UC_g', 4],
#  [u'9qrnpeUiGHNcmgBK11Ur9Q', 4],
#  [u'kcbVbk_I9sv3Y1WFLZrTvA', 4],
#  [u'n_BUkkkPKhfBzk18XughbQ', 3],
#  [u'_CluaKgvh7d0Ql7iqlWBxg', 4],
#  [u'jVpBZebxO-xRfmSkal6how', 4],
#  [u'HHlvzwce4vk9NiijaavgiA', 3],
#  [u'epJn4Z09XvT-j9P3xyi5UA', 4],
#  [u'PzA_J-aGhcKa0IcGVA_w4Q', 2],
#  [u'pKMkdzDPf7d0pzdJmalZww', 4],
#  [u'O8Ktl_ZRYix5Gc4u6yrVjA', 4],
#  [u'jiP-UOjCPTzKMnKjRPsbUg', 4],
#  [u'roJb_bISijScLgRgp6ovYw', 4],
#  [u'tkNVBB_cdfpUsXOiRfR7qw', 4],
#  [u'iFVJfK3AO1VIxDaqEfwR2w', 4],
#  [u'_bUDYHMbFSgQukBDwIxdFQ', 4],
#  [u'pedSbaC_luY8aZYjPCLSow', 4],
#  [u'G87JVdjnhn-a-q-6dQU-8Q', 3],
#  [u'NWo_n4Ir4NT2j2ABnx6ZDA', 4],
#  [u'kvkEzp_s5o6cmAlWiBasOA', 3],
#  [u'i-pn6pq7MRxp-CdR57TkDw', 2],
#  [u'fSWU7nDr2Xl1H3KcSlSwkg', 4],
#  [u'ZUHG3uFcf8FMUTd_UdlBnQ', 4],
#  [u'xapPjpUX_XaVdby78oVMgA', 4],
#  [u'4-aBhA96hhdMvOfVOt-ZdQ', 3],
#  [u'7zL68QeQn_dcpmCPuxQcGA', 2],
#  [u'5CTBG3jJmRY-TMgLJ8dE_g', 4],
#  [u'NQYLorAlrxJ3bMEEtQuDxA', 4],
#  [u'cz1WdHDQDZnSsFgls6yU8Q', 4],
#  [u'ok8laV4kn5_7YZsxkwza6Q', 4],
#  [u'w1JGjlrxEJE8nfIjy-UjWQ', 4],
#  [u'MUs0mpBUKQQyYzI1ddFeMg', 4],
#  [u't25C3HoIMYJOg0vcZDu63A', 4],
#  [u'ZJeOUH8Lujo_cfMviK8zlA', 1],
#  [u'fRcQT44OQxvNHB1CNqujuw', 2],
#  [u'uYlw8zIwwkg_QJxyy6d-tQ', 4],
#  [u'hV1TqyDdsTzzcyptQ0K3Xg', 4],
#  [u'UboynuyM46fh6lFEMZIEIg', 4],
#  [u'SJiwGoLkUO87BuqegtrFGg', 4],
#  [u'MHQnia4y8D8ojAMxDJ182Q', 2],
#  [u'O3cw28pj9VtiycNWxSYrNQ', 3],
#  [u'eXLHTZiYalwUfS-NplFBUQ', 3],
#  [u'STuEpr1oxFWvlobVSMIfWg', 4],
#  [u'3ysHNt5Utq1XXVRuwkJapg', 4],
#  [u'QU-ISFidohW_vMhnRbWh2w', 3],
#  [u'bdl63MRpMvbCdc5_I3be7w', 2],
#  [u'U3W0z788pGQArpN67vWA1Q', 4],
#  [u'zq22S6f8_-FE8gvJtoZq-w', 2],
#  [u'WxjKfOMfDk7yzyV8i-e58Q', 4],
#  [u'YmHim_2Lf3zoyFaQ5lFhDQ', 4],
#  [u'4E1DWU94hBdHU2SwSjP-Ew', 1],
#  [u'q4S6htzBe8t5vrS-t7zrdA', 1],
#  [u'u78cdvg8Q913Cdf0cazufw', 4],
#  [u'pHFO4C44Nm5c1Agtjb7Atw', 4],
#  [u'tcaOfYEYSgo5VoaOWng6eQ', 3],
#  [u'ZAui89gbnPr0uvvInx99jA', 5],
#  [u'3_Ct16y0Xr1s75RAwISH1w', 4],
#  [u'qldzFeOFLPsEdFrXSoa1iw', 4],
#  [u'5d9dAWeTYt54eUjGxdk9Fw', 4],
#  [u's9fR_sMz3DzdlEF0buWPMQ', 4],
#  [u'mcrOpERz6RO1FGs-lVxaFw', 2],
#  [u'EuahA00mmfEVKX7JkCQ6Ww', 4],
#  [u'bSlIqQBkvAfiuSzlvO63QA', 3],
#  [u'T9gCnJk9qNMAeykZoOU1Ww', 3],
#  [u'S2O99LO58_Lu4zTT92JU4A', 4],
#  [u'L6LM6NyvMnJ4-QebWGOsDg', 4],
#  [u'q6x5-kg3RcRqmd2K2P9bvg', 4],
#  [u'sQzoWdmXCIyRSYxElD6LUg', 2],
#  [u'B7-3pEGJPLVqBMc0vx-qvA', 4],
#  [u'cMj1kEJJL3qKo3wn-Wlo9Q', 4],
#  [u'VV1XKY6Shs24-_zXk2M8RA', 4],
#  [u'D-VVG6xp8NhdyLB7-CsodQ', 4],
#  [u'Uxc8GlRpdyZAvV4R6hCXqA', 4],
#  [u'vK4cJu6wVGkZWuPNCkCA5Q', 4],
#  [u'VqGd3aWaNZl18wpX5uij_w', 4],
#  [u'-3yKuIrEVxaLcvLV5G40vg', 4],
#  [u'J9rcL8sHPibgfQYWtxQ3DQ', 4],
#  [u'4DervwHMYJVvneduNIsSVQ', 4],
#  [u'79GNfhXXk3pDQPTd06UDSQ', 4],
#  [u'LTC5tZw6h8HEbqY9MDTrug', 4],
#  [u'xGnv44HMJTzHqCrOxXx0QQ', 4],
#  [u'NzF2g_zQ90iUCQh1U_7lKw', 4],
#  [u'MeaLuBvAekpRHrkC40Pjbw', 4],
#  [u'GhS8yIi9wsY6DeystDfDhQ', 5],
#  [u'ACfwBG-V0wDV3xbaNDRbJA', 4],
#  [u'5RMJMSAKvKAy_SMLeCu1jQ', 4],
#  [u'jz9QHp9XZzmJBRW5Oi0SjQ', 4],
#  [u'hWBIlPp9hHOvq55dvLkBkg', 4],
#  [u'fOioulKqb-kQUwTNv5aYOg', 2],
#  [u'_fJSlX5fKAruTjMxVWB2JQ', 4],
#  [u'spEi9obFDF9q9eP-_BMMww', 4],
#  [u'T9Uh3sEPqXKNXxX7U_5RBQ', 4],
#  [u'XPr7h9Gdc9y16oxED0q5iw', 4],
#  [u'14nBOgqzAyc_S09pBDp_Kg', 4],
#  [u'Y4NDfMMGIc6LjJ9ERNy38A', 4],
#  [u'y_U72SBctKSmq34qE90bLw', 4],
#  [u'xBvoQRDIlEIt139VXGI88g', 4],
#  [u'Po9_V3JjWDuVkBqhtQdZ6w', 4],
#  [u'HWrft2dlKz1Eku_rt75qbA', 1],
#  [u'OQ0azXSsOBo5EUZAu8pDWA', 1],
#  [u'ervZbxKXzNJZX3ZJ0y9Ckw', 1],
#  [u'aJKTVum91hp_TitwG2ki2A', 0],
#  [u'wbWACYZ0Gb5l_ptd5JBT5g', 4],
#  [u'pev6a8dw01IsMun6qxgszA', 1],
#  [u'tfPMyu5HbhpbWfEVmkDKEA', 4],
#  [u'JHzqaLtUV5hc-Gc5Y2wKHg', 4],
#  [u'4UvtviiF17qCuqoU-r0krQ', 4],
#  [u'bgmSJ5Z0jobDMTIk9HSAkQ', 4],
#  [u'UxGGkyCmyBJWhx46JNtZpQ', 2],
#  [u'IbL1SJ_IhJjsnpF-UtlRzw', 4],
#  [u'_eO42tMtsC724bdAZIKb0g', 1],
#  [u'2sQH970ofXg5vKjAWW_DAg', 4],
#  [u'tQSIL0Xq825OGwtHOGAZNQ', 4],
#  [u'r78VtnXEN27Nxl-N27po4g', 4],
#  [u'6VgI4ZOmgFE9Cw5SzvJ1XQ', 2],
#  [u'q6nZAdIKclQmoibvzQgdCA', 5],
#  [u'AqGr6nbr6bDj2c2M3OLwWw', 1],
#  [u'iEdpXp_-GyA7NQh80GY-BA', 0],
#  [u'F3-NLBMd49TvF55BSNbLtA', 2],
#  [u'NO1YA0Rbv3JAT7OEFSUK0A', 5],
#  [u'6I_KE1ffZhO4fFA0-Ct55w', 4],
#  [u'wGDGIKdyK8c4tuOSmlv1rQ', 4],
#  [u'46ZpNVQnJ_Va5qeN_dcm6Q', 4],
#  [u'LwIknaXelqi7Gwtibh1xxQ', 4],
#  [u'g1u7k0AzRUQz_3zZZfQw5Q', 4],
#  [u'6AjGhegv69JMwLU9EnL9fQ', 0],
#  [u'Qo9Oabe8oL5nWuk2xgwvFQ', 1],
#  [u'M5dUmiRUgmIfXJsgewmV5g', 4],
#  [u'_MZWYNOMrTotSNNhEsUpRA', 4],
#  [u'ON9XHfQ6APZtC-bduV6OlQ', 4],
#  [u'cGrFU8aQLvaaZetCvNYbIw', 4],
#  [u'PBkoV0h-GKeYpZAcnfrzzg', 2],
#  [u'81H2Edsb2WssBSPp-qa2Sg', 4],
#  [u'T5zIHOPj-Gu5etlROwg9Ew', 2],
#  [u'Z2zwngYci-zFWLtQse3VcQ', 2],
#  [u'OruagW2ZgP6cKrF29H9biw', 0],
#  [u'kQ1zs2ydZ45lh6UWJc-FKg', 4],
#  [u'c-6Tz7vVHKwaOtZoXDjgQQ', 2],
#  [u'1xG46P-xgon1D_ozhPu8Ug', 4],
#  [u'tzPvQD5WYGeIQLii19Y0Ig', 4],
#  [u'7LBH3WpoahMToHpAII6z9Q', 4],
#  [u'ciZ5fmoFMLEejNRvw_6PCQ', 4],
#  [u'E4h8x0yIS55nyI2VudQ5iA', 4],
#  [u'5KKs_1HkKgdZNqD5LOdR5g', 3],
#  [u'3vRQB9ILkwq0KrkAHdmGAw', 4],
#  [u'X-s6WZ5hFUN7ZHmjS_c6GQ', 4],
#  [u'5uOagXfu8VdRYgERVXa6OQ', 4],
#  [u'bJayaYbxw3qF9fMRvRM-9g', 4],
#  [u'ss_b9OhPPDsS4CX22-pgGA', 4],
#  [u'xfGOIR4k6kg1g9E76cEI5g', 3],
#  [u'A1codKdeDqtDRHh2gu3xZQ', 4],
#  [u'TRZ2EMM3AKg_7riGjAQrsw', 4],
#  [u'QVahhhKFSTYmm6tfX1egBA', 4],
#  [u'FuVDLT6F0O4aNhq6LU0JmA', 4],
#  [u'k27rvwXljdrFW9G-eU4kcw', 3],
#  [u'yo_JARvQQSxwCQHtmzHNJQ', 2],
#  [u'j_NQSMT2fEppiGJO9bQraA', 4],
#  [u'oU8nq_7GQpleSsvacD5JDw', 4],
#  [u'O7jaIT6LKnaLoeR3o6rwhQ', 4],
#  [u'oS7bLyLc5XlYNDlKYgtpLg', 4],
#  [u'm6Y5HMrGWFgohfzO4RrTvw', 1],
#  [u'BUvGNrops6SWhjOiVtZ_iQ', 4],
#  [u'G4u6pYnEWWXr7X1nPb628w', 4],
#  [u'DEdutUIH1kP82LEl5POpAQ', 4],
#  [u'nAEyabfZ86z9AyxYEvPKsQ', 2],
#  [u'kDSRyXx9j_ZzD_Yfe3_4UQ', 2],
#  [u'rofKyQggIBOsOkhy0OE4gg', 4],
#  [u'QdJh3vzwpi4ULFBYZw3ewQ', 0],
#  [u'NJlohmlMSslQLrtF9r6jrQ', 4],
#  [u'YMo5ut8RB54OssTLK9h5bw', 4],
#  [u'TaOIZvkw0Gd2zm_7_Nw2qA', 4],
#  [u'0CwROQ9ZHgCHZ9zgXAj7Ig', 4],
#  [u'aF0CYD9Zbcjvyg8mDlF9Dg', 2],
#  [u'FHLJHStsyhKpOvfZJWPcXw', 2],
#  [u'ak8aev3WMQhT1lCJmrdieg', 4],
#  [u'C5AUjN0wL8TCmU7a6gtMnw', 4],
#  [u'HsQJXNBEdHh2uZUhuFNQtw', 1],
#  [u'oQvP0PSG11NkdQ6vRJuU5Q', 5],
#  [u'6MK0YUI40FCXMD33GMjIlg', 2],
#  [u'f05MAkYVRQ1lQGHRRYXhnA', 4],
#  [u'Fo7eWGi_SPFlaek9v6xTlg', 5],
#  [u'_wHMDHmIZ_e_nJEDwsPywQ', 4],
#  [u'e4yMhpoS4xt_-Z5MylMHPQ', 4],
#  [u'kCDouew1Xth6Fsuw8P_2AA', 2],
#  [u'GDQWIIVqhoUplqkVyFQn9w', 4],
#  [u'PFkOdKStiqsq8_Dcd5RLPg', 1],
#  [u'YwsvVlxrIYmxGlxtiUoxjA', 4],
#  [u'lbBiKX67X1Kkhc6pdowpAQ', 4],
#  [u'RtnHT-iZV5X7OCfgNupMfA', 4],
#  [u'umDbT1pbLOztMRv2jcM3Zg', 4],
#  [u'Fq1S4zIPwsWflEoeY_3LFA', 1],
#  [u'90WYNLX6gDBErZFefUvB0g', 4],
#  [u'koSHdBi7p0myYGNg6o-Ypg', 4],
#  [u'TsoOQB1VkGhrcfIK-aWiMw', 3],
#  ...]

# %%
results = pd.DataFrame(data=prediction,columns=['review_id','stars'])

# %%
results.to_csv('data/submission.csv',index=False)
